# %% [markdown]
# # Task_2

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
pwd
# Out:
# '/Users/puranshu'

# %%
cd /Users/puranshu/Desktop/ML_task
# Out:
# /Users/puranshu/Desktop/ML_task

# %%
file = pd.read_csv(r'task2.csv') #1. Open Data

# %%
file
# Out:
#                ID Segment type Segment Description Answer        Count  \
# 0     292890.8970          web     Meridian, Idaho     No     0.000000
# 1     292887.9870          web     Meridian, Idaho     No     0.000000
# 2     292894.0656       gender     Meridian, Idaho     No   499.173606
# 3     292887.1180          web     Meridian, Idaho     No     0.000000
# 4     292893.6561       gender     Meridian, Idaho     No   455.925963
# ...           ...          ...                 ...    ...          ...
# 1891  292887.5496          web     Meridian, Idaho     No     0.000000
# 1892  292881.6932       mobile     Meridian, Idaho     No  1203.190399
# 1893  292900.8499       gender     Meridian, Idaho     No   806.378820
# 1894  292893.8600       gender     Meridian, Idaho     No  1149.529381
# 1895  292890.2944          web     Meridian, Idaho     No     0.000000
#
#       Percentage  It became a relationship
# 0       0.000000                         0
# ...

# %%
file.isnull().sum() #2. Check missing variables
# Out:
# ID                          0
# Segment type                0
# Segment Description         0
# Answer                      0
# Count                       0
# Percentage                  0
# It became a relationship    0
# dtype: int64

# %%
sns.heatmap(file.isnull(),yticklabels=False,cbar=False,cmap='viridis') # No NaN values
# Out:
# <AxesSubplot:>

# %%
file
# Out:
#                ID Segment type Segment Description Answer        Count  \
# 0     292890.8970          web     Meridian, Idaho     No     0.000000
# 1     292887.9870          web     Meridian, Idaho     No     0.000000
# 2     292894.0656       gender     Meridian, Idaho     No   499.173606
# 3     292887.1180          web     Meridian, Idaho     No     0.000000
# 4     292893.6561       gender     Meridian, Idaho     No   455.925963
# ...           ...          ...                 ...    ...          ...
# 1891  292887.5496          web     Meridian, Idaho     No     0.000000
# 1892  292881.6932       mobile     Meridian, Idaho     No  1203.190399
# 1893  292900.8499       gender     Meridian, Idaho     No   806.378820
# 1894  292893.8600       gender     Meridian, Idaho     No  1149.529381
# 1895  292890.2944          web     Meridian, Idaho     No     0.000000
#
#       Percentage  It became a relationship
# 0       0.000000                         0
# ...

# %%
file = file.iloc[0:,1:7]

# %%
file
# Out:
#      Segment type Segment Description Answer        Count  Percentage  \
# 0             web     Meridian, Idaho     No     0.000000    0.000000
# 1             web     Meridian, Idaho     No     0.000000    0.000000
# 2          gender     Meridian, Idaho     No   499.173606    0.225255
# 3             web     Meridian, Idaho     No     0.000000    0.000000
# 4          gender     Meridian, Idaho     No   455.925963    0.211360
# ...           ...                 ...    ...          ...         ...
# 1891          web     Meridian, Idaho     No     0.000000    0.000000
# 1892       mobile     Meridian, Idaho     No  1203.190399    0.312360
# 1893       gender     Meridian, Idaho     No   806.378820    0.488025
# 1894       gender     Meridian, Idaho     No  1149.529381    0.488984
# 1895          web     Meridian, Idaho     No     0.000000    0.000000
#
#       It became a relationship
# 0                            0
# 1                            0
# ...

# %%
seg_type = pd.get_dummies(file['Segment type'])
seg_type = seg_type.drop('gender',axis=1)
seg_type
# Out:
#       mobile  university  web
# 0          0           0    1
# 1          0           0    1
# 2          0           0    0
# 3          0           0    1
# 4          0           0    0
# ...      ...         ...  ...
# 1891       0           0    1
# 1892       1           0    0
# 1893       0           0    0
# 1894       0           0    0
# 1895       0           0    1
#
# [1896 rows x 3 columns]

# %%
seg_dcpt = pd.get_dummies(file['Segment Description'])
seg_dcpt = seg_dcpt.drop('Appalachian State University',axis=1)
seg_dcpt
# Out:
#       Arizona State University  Arkansas State University  Auburn University  \
# 0                            0                          0                  0
# 1                            0                          0                  0
# 2                            0                          0                  0
# 3                            0                          0                  0
# 4                            0                          0                  0
# ...                        ...                        ...                ...
# 1891                         0                          0                  0
# 1892                         0                          0                  0
# 1893                         0                          0                  0
# 1894                         0                          0                  0
# 1895                         0                          0                  0
#
# ...

# %%
ans = pd.get_dummies(file['Answer'])
ans = ans.drop("I don't use Tinder",axis=1)
ans
# Out:
#       No  Yes
# 0      1    0
# 1      1    0
# 2      1    0
# 3      1    0
# 4      1    0
# ...   ..  ...
# 1891   1    0
# 1892   1    0
# 1893   1    0
# 1894   1    0
# 1895   1    0
#
# [1896 rows x 2 columns]

# %%
file = file.drop(['Segment Description', 'Answer', 'Segment type'], axis=1)
file = pd.concat([file,seg_type,seg_dcpt,ans], axis=1)

# %%
file #Converted every string into numerical form by using dummy variables
# Out:
#             Count  Percentage  It became a relationship  mobile  university  \
# 0        0.000000    0.000000                         0       0           0
# 1        0.000000    0.000000                         0       0           0
# 2      499.173606    0.225255                         0       0           0
# 3        0.000000    0.000000                         0       0           0
# 4      455.925963    0.211360                         0       0           0
# ...           ...         ...                       ...     ...         ...
# 1891     0.000000    0.000000                         0       0           0
# 1892  1203.190399    0.312360                         0       1           0
# 1893   806.378820    0.488025                         0       0           0
# 1894  1149.529381    0.488984                         0       0           0
# 1895     0.000000    0.000000                         0       0           0
#
# ...

# %%
#3. Spilt Data in 2 parts
X_final=file.drop('It became a relationship',axis =1)
y_final=file['It became a relationship']

# %%
X_final.shape
# Out:
# (1896, 154)

# %%
y_final.shape
# Out:
# (1896,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_final, y_final, test_size=0.2)

# %% [markdown]
# ## Model_1

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Model_1_a

# %%
model_1_a = DecisionTreeClassifier(random_state=0,max_depth=30)

model_1_a = model_1_a.fit(X_train,y_train)

y_pred_1_a = model_1_a.predict(X_test)

confusion_matrix(y_test,y_pred_1_a)
# Out:
# array([[241,  16],
#        [ 28,  95]])

# %%
accuracy_score(y_test,y_pred_1_a)
# Out:
# 0.8842105263157894

# %% [markdown]
# ### Model_1_b

# %%
model_1_b = DecisionTreeClassifier(random_state=1,max_depth=60)

model_1_b = model_1_b.fit(X_train,y_train)

y_pred_1_b = model_1_b.predict(X_test)

confusion_matrix(y_test,y_pred_1_b)
# Out:
# array([[239,  18],
#        [ 28,  95]])

# %%
accuracy_score(y_test,y_pred_1_b)
# Out:
# 0.8789473684210526

# %% [markdown]
# ### Model_1_c

# %%
model_1_c = DecisionTreeClassifier(random_state=42,max_depth=90)

model_1_c = model_1_c.fit(X_train,y_train)

y_pred_1_c = model_1_c.predict(X_test)

confusion_matrix(y_test,y_pred_1_c)
# Out:
# array([[241,  16],
#        [ 28,  95]])

# %%
accuracy_score(y_test,y_pred_1_c)
# Out:
# 0.8842105263157894

# %% [markdown]
# How to choose good depth (WHICH GIVES YOU MAXIMUM ACCURACY)

# %%
#for i in range(1,100):
    #model = DecisionTreeClassifier(max_depth =i)
    #model = model.fit(X_train,y_train)
    #y_pred = model.predict(X_test)
    #print(i, accuracy_score(y_test,y_pred))

# %% [markdown]
# ## Model_2

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### Model_2_a

# %%
model_2_a = RandomForestClassifier(n_estimators=20, criterion="gini",  n_jobs=-1, random_state=101, 
                                   max_features = 154, min_samples_leaf = 10)#n_jobs=-1 means all processor and max_feature = 154 (total features in new data set)
model_2_a = model_2_a.fit(X_train,y_train)

y_pred_2_a = model_2_a.predict(X_test)

confusion_matrix(y_test,y_pred_2_a)
# Out:
# array([[231,  26],
#        [ 10, 113]])

# %%
accuracy_score(y_test,y_pred_2_a)
# Out:
# 0.9052631578947369

# %% [markdown]
# ### Model_2_b

# %%
model_2_b = RandomForestClassifier(n_estimators=50, criterion="entropy", n_jobs=-1, random_state=1, 
                                   max_features = 154, min_samples_leaf = 20) #n_jobs=-1 means all processor and max_feature = 154 (total features in new data set)
model_2_b = model_2_b.fit(X_train,y_train)

y_pred_2_b = model_2_b.predict(X_test)

confusion_matrix(y_test,y_pred_2_b)
# Out:
# array([[232,  25],
#        [ 21, 102]])

# %%
accuracy_score(y_test,y_pred_2_b)
# Out:
# 0.8789473684210526

# %% [markdown]
# ### Model_2_c

# %%
model_2_c = RandomForestClassifier(n_estimators=80, criterion="gini", n_jobs=-1, random_state=1, 
                                   max_features = 154, min_samples_leaf = 30) #n_jobs=-1 means all processor and max_feature = 154 (total features in new data set)
model_2_c = model_2_c.fit(X_train,y_train)

y_pred_2_c = model_2_c.predict(X_test)

confusion_matrix(y_test,y_pred_2_c)
# Out:
# array([[230,  27],
#        [ 24,  99]])

# %%
accuracy_score(y_test,y_pred_2_c)
# Out:
# 0.8657894736842106

# %% [markdown]
# How to check ideal estimator (WHICH GIVES YOU MAXIMUM ACCURACY)

# %%
#for i in range(1,100):
    #model = RandomForestClassifier(n_estimators=i, n_jobs=-1, random_state=1, max_features = None, min_samples_leaf = 50)
    #model = model.fit(X_train,y_train)
    #y_pred = model.predict(X_test)
    #print(i, accuracy_score(y_test,y_pred))
